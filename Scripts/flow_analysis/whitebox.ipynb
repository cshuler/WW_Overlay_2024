# %%
import sys

# Add the folder where whitebox_tools.py is located
sys.path.append(r"C:\WhiteboxTools\WBT")

# %%
from whitebox_tools import WhiteboxTools

# Create a WhiteboxTools object
wbt = WhiteboxTools()

# Optional: tell it where the executables live
wbt.exe_path = r"C:\WhiteboxTools\WBT"

# %%
print(wbt.version())
# Out:
# WhiteboxTools v2.4.0 (c) Dr. John Lindsay 2017-2023
#
# WhiteboxTools is an advanced geospatial data analysis platform developed at
# the University of Guelph's Geomorphometry and Hydrogeomatics Research
# Group (GHRG). See www.whiteboxgeo.com for more details.

# %%
dem = r"C:\GIS\ElevUTM\maui.tif"

# %%
#filled = r"C:\GIS\test\filltest.tif"
#wbt.fill_depressions(dem, filled)

# %%
sloperaster = r"C:\GIS\test\slopetest3.tif"

wbt.slope(
    dem, 
    sloperaster, 
    zfactor=None, 
    units="degrees"
)
# Out:
# .\whitebox_tools.exe --run="Slope" --dem='C:\GIS\ElevUTM\maui.tif' --output='C:\GIS\test\slopetest3.tif' --units=degrees -v --compress_rasters=False
#
# ****************************
# * Welcome to Slope         *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# ...

# %%
wbt.d8_flow_accumulation(
    dem, 
    "C:\GIS\test\maui_flow_acc.tif", 
    out_type="cells", 
    log=False, 
    clip=False, 
    pntr=False, 
    esri_pntr=False, 
)
# Out:
# .\whitebox_tools.exe --run="D8FlowAccumulation" --input='C:\GIS\ElevUTM\maui.tif' --output='C:\GIS	est\maui_flow_acc.tif' --out_type=cells -v --compress_rasters=False
#
# *********************************
# * Welcome to D8FlowAccumulation *
# * Powered by WhiteboxTools      *
# * www.whiteboxgeo.com           *
# *********************************
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\JPL\AppData\Local\Temp\ipykernel_23816\269087112.py:3: SyntaxWarning: invalid escape sequence '\G'
#   "C:\GIS\test\maui_flow_acc.tif",
# Reading data...
# Flow directions: 0%
# Flow directions: 1%
# Flow directions: 2%
# Flow directions: 3%
# Flow directions: 4%
# Flow directions: 5%
# Flow directions: 6%
# Flow directions: 7%
# Flow directions: 8%
# Flow directions: 9%
# Flow directions: 10%
# Flow directions: 11%
# Flow directions: 12%
# Flow directions: 13%
# Flow directions: 14%
# Flow directions: 15%
# ...

# %%
wbt.fill_depressions(dem, r"C:\GIS\test\mauifill.tif")
# Out:
# .\whitebox_tools.exe --run="FillDepressions" --dem='C:\GIS\ElevUTM\maui.tif' --output='C:\GIS\test\mauifill.tif' --fix_flats -v --compress_rasters=False
#
# ******************************
# * Welcome to FillDepressions *
# * Powered by WhiteboxTools   *
# * www.whiteboxgeo.com        *
# ******************************
# Reading data...
# Finding pit cells: 5%
# Finding pit cells: 10%
# Finding pit cells: 15%
# Finding pit cells: 20%
# Finding pit cells: 25%
# Finding pit cells: 30%
# Finding pit cells: 35%
# Finding pit cells: 40%
# Finding pit cells: 45%
# Finding pit cells: 50%
# Finding pit cells: 55%
# Finding pit cells: 60%
# Finding pit cells: 65%
# Finding pit cells: 70%
# Finding pit cells: 75%
# Finding pit cells: 80%
# Finding pit cells: 85%
# Finding pit cells: 90%
# Finding pit cells: 95%
# Finding pit cells: 100%
# Filling depressions: 0%
# Filling depressions: 1%
# Filling depressions: 2%
# Filling depressions: 3%
# Filling depressions: 4%
# Filling depressions: 5%
# ...

# %%
wbt.d8_pointer(r"C:\GIS\test\mauifill.tif",r"C:\GIS\test\maui_fill_flowdir.tif")
# Out:
# .\whitebox_tools.exe --run="D8Pointer" --dem='C:\GIS\test\mauifill.tif' --output='C:\GIS\test\maui_fill_flowdir.tif' -v --compress_rasters=False
#
# ****************************
# * Welcome to D8Pointer     *
# * Powered by WhiteboxTools *
# * www.whiteboxgeo.com      *
# ****************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# Progress: 35%
# Progress: 36%
# Progress: 37%
# Progress: 38%
# Progress: 39%
# Progress: 40%
# Progress: 41%
# Progress: 42%
# ...

# %%
wbt.trace_downslope_flowpaths(
    r"C:\GIS\test\maui_fill_flowdir.tif",
    r"C:\GIS\plats\maui_plats_centroids.shp",
    r"C:\GIS\test\output\maui_flowpaths.shp"
)
# Out:
# .\whitebox_tools.exe --run="TraceDownslopeFlowpaths" --seed_pts='C:\GIS\test\maui_fill_flowdir.tif' --d8_pntr='C:\GIS\plats\maui_plats_centroids.shp' --output='C:\GIS\test\output\maui_flowpaths.shp' -v --compress_rasters=False
#
# **************************************
# * Welcome to TraceDownslopeFlowpaths *
# * Powered by WhiteboxTools           *
# * www.whiteboxgeo.com                *
# **************************************
# Reading flow direction data...
# thread 'main' panicked at whitebox-tools-app\src\main.rs:72:21:
# Unrecognized raster type
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# 0
